# %% [markdown]
# ![image.png](attachment:c145b544-f624-413f-9cd1-49c33f57bb25.png)

# %% [markdown]
# **Briefly describe the context for the visual by addressing the following questions:**
#
# **1.What is the source of the visual? (e.g., URL or bibliographic citation)**
#
# *[https://viz.wtf/post/673291209724329984/fun-activity-draw-the-rest-of-the-circular-pie](http://)*
#
#
# **2.Who is the intended audience (i.e., decoders)? How do you know this?**
#
# *American Citizens is the intended audience.*
#
# **3.Identify the specific component(s) of the visual that is/are misleading**
#
# *The visual is using graphic forms in appropriate ways ( distorting the data)*
#
# **4.For each part(s) of the visualization that is/are misleading, identify the mechanism that is used: hiding relevant data to highlight what benefits us; displaying too much data to obscure reality; using graphic forms in inappropriate ways (distorting the data)**
#
# *The percentage distribution area is uneven.*
#
# **5.Explain how the mechanisms are used to mislead**
#
# *The visual is trying to emphasize on the least supported idea of a survey by highlighting it with red color and making the distribution area bigger as compared to other two categories.*
